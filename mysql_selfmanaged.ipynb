# %%
# !sudo apt-get install python3-dev default-libmysqlclient-dev
# !pip install pymysql sqlalchemy
# !pip install pymysql
from sqlalchemy import create_engine
import sqlalchemy
import pandas as pd
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# default-libmysqlclient-dev is already the newest version (1.0.4).
# python3-dev is already the newest version (3.6.7-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
MYSQL_HOSTNAME = '34.69.118.129' 
MYSQL_USER = 'fizzah'
MYSQL_PASSWORD = 'ahi2022'
MYSQL_DATABASE = 'db1'

# %%
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
connection_string
# Out:
# 'mysql+pymysql://fizzah:ahi2022@34.69.118.129/db1'

# %%
db1 = create_engine(connection_string)
db1
# Out:
# Engine(mysql+pymysql://fizzah:***@34.69.118.129/db1)

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/zf81/mysql-selfmanaged/main/data/literacy-rates.csv')
df1
# Out:
#       index                     Region      Country  Year    Age  Gender  \
# 0         0  Central and Southern Asia  Afghanistan  2011    15+  female
# 1         1  Central and Southern Asia  Afghanistan  2011    15+    male
# 2         2  Central and Southern Asia  Afghanistan  2011    15+   total
# 3         3  Central and Southern Asia  Afghanistan  2011  15-24  female
# 4         4  Central and Southern Asia  Afghanistan  2011  15-24    male
# ...     ...                        ...          ...   ...    ...     ...
# 4950   4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951   4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952   4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953   4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954   4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#       Literacy rate
# 0          0.176121
# 1          0.454171
# 2          0.317411
# ...

# %%
df1.to_sql('Literacy_rates',con=db1,if_exists='replace')

# %%
query1 = """select * from db1.Literacy_rates where year >= 2017"""

# %%
LR_db_test = pd.read_sql(query1, con=db1)
LR_db_test
# Out:
#       level_0  index                     Region      Country  Year    Age  \
# 0          11     11  Central and Southern Asia  Afghanistan  2018    15+
# 1          12     12  Central and Southern Asia  Afghanistan  2018    15+
# 2          13     13  Central and Southern Asia  Afghanistan  2018    15+
# 3          14     14  Central and Southern Asia  Afghanistan  2018  15-24
# 4          15     15  Central and Southern Asia  Afghanistan  2018  15-24
# ...       ...    ...                        ...          ...   ...    ...
# 1225     4926   4926         Sub-Saharan Africa       Zambia  2018  25-64
# 1226     4927   4927         Sub-Saharan Africa       Zambia  2018  25-64
# 1227     4928   4928         Sub-Saharan Africa       Zambia  2018    65+
# 1228     4929   4929         Sub-Saharan Africa       Zambia  2018    65+
# 1229     4930   4930         Sub-Saharan Africa       Zambia  2018    65+
#
#       Gender  Literacy rate
# 0     female       0.298052
# ...
